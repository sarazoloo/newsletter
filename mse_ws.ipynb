# %%
import feedparser 
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from requests_html import HTMLSession
from datetime import datetime

# %%
#mse rss feed
m = feedparser.parse('https://www.mse.mn/en/feed')

try:
    rows = []
    for j in range(1, len(m.entries)):
        title = m.entries[j].title
        link = m.entries[j].link
        date = m.entries[j].published
        description = m.entries[j].description
        category = 'Finance'
        
        row_dict = {'Title':title, 'Date':date, 'Link':link, 'Category':category, 'Description':description}
        rows.append(row_dict)
        
        mse = pd.DataFrame(rows)
        
except Exception as e:
    print(e)

# %%
mse['Date'] = mse['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %%
mse['Date'] = mse['Date'].apply(lambda x: datetime.strftime(x, '%Y-%m-%d'))

# %%
mse.to_csv('/datasets/webscrape/mse_'+ datetime.now().strftime('%m_%d_%y.csv'), index_label = 'id')

# %%
mse
# Out:
#                                                Title        Date  \
# 0  "ERDENE RESOURCE DEVELOPMENT" JSC  INTERSECTS ...  2022-10-28
# 1                    OCTOBER 27, 2022 TRADING REPORT  2022-10-27
# 2                    OCTOBER 26, 2022 TRADING REPORT  2022-10-26
# 3                    OCTOBER 25, 2022 TRADING REPORT  2022-10-25
# 4                    OCTOBER 24, 2022 TRADING REPORT  2022-10-24
# 5  "ERDENE RESOURCE DEVELOPMENT CORPORATION" JSC ...  2022-10-24
# 6                              WEEKLY TRADING REPORT  2022-10-24
# 7                    OCTOBER 21, 2022 TRADING REPORT  2022-10-21
# 8                    OCTOBER 20, 2022 TRADING REPORT  2022-10-20
#
#                           Link Category  \
# 0  http://mse.mn/en/news/10203  Finance
# 1  http://mse.mn/en/news/10201  Finance
# 2  http://mse.mn/en/news/10199  Finance
# 3  http://mse.mn/en/news/10197  Finance
# 4  http://mse.mn/en/news/10195  Finance
# 5  http://mse.mn/en/news/10194  Finance
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=beeb4017-97f4-440a-94d7-340a7ca71887' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
